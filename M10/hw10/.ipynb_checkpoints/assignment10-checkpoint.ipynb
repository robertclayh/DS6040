# %% [markdown]
# # Assignment 10
#
# In this assignment we'll examine a data set in `diabetes.csv`.
#
# ## Instructions
#
# Please complete this Jupyter notebook and **don't** convert it to a `.py` file. Upload this notebook, along with any `.stan` files and any data sets as a `zip` file to Gradescope. Your work will be manually graded by our TA.
#
# Protip: if you write your `.stan` file generally enough, it will work with most of the models below, and you won't need to keep recompiling the model object!

# %%
import pandas as pd
import numpy as np
import os
from cmdstanpy import CmdStanModel
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from numpy.linalg import inv

# %% [markdown]
# ## Data Description
#
# This dataset is originally from
#
#     Reaven, G. M. and Miller, R. G. (1979). An attempt to define the nature of chemical diabetes using a multidimensional analysis. Diabetologia, 16, 17-24.
#
# The `group` column provides labels that the researches came up with. They should not be taken as fact or used in your finite mixture model (because they are discrete). Interestingly, the labels provided can be used to compare with the labels you might generate from your model.

# %%
diab = pd.read_csv("diabetes.csv")
diab.head()
# Out:
#    relwt  glufast  glutest  instest  sspg   group
# 0   0.81       80      356      124    55  Normal
# 1   0.95       97      289      117    76  Normal
# 2   0.94      105      319      143   105  Normal
# 3   1.04       90      356      199   108  Normal
# 4   1.00       90      323      240   143  Normal

# %% [markdown]
# ## Problem 1:
#
# In general, if your data has $D$ columns, and you assume your model has $H$ clusters, how many parameters in total are there for
#
#  - the general case of fully flexible covariance matrices,
#  - assuming all groups have the same general covariance structure,
#  - assuming variables are uncorrelated in all groups, and
#  - assuming that in every group, all features have the same variance *and* are uncorrelated with one another?

# %% [markdown]
# Let D be the number of columns (features) and H be the number of clusters. The total number of parameters in each scenario is:
#
# - **General case (fully flexible covariance matrices):**
#   Each group has a mean vector of length D and a D x D covariance matrix with D(D+1)/2 unique parameters.
#   Total: H × [D + D(D+1)/2] = H × (D + D(D+1)/2)
#
# - **Same general covariance structure across all groups:**
#   One shared covariance matrix (D(D+1)/2 parameters), and H mean vectors.
#   Total: H × D + D(D+1)/2
#
# - **Variables uncorrelated in all groups:**
#   Each covariance matrix is diagonal → D variances per group.
#   Total: H × (D + D) = H × 2D
#
# - **Same variance and uncorrelated in all groups:**
#   One variance shared across all features and groups (1 parameter), and H mean vectors.
#   Total: H × D + 1

# %% [markdown]
# ## Problem 2: Inference on $\theta$ and $z$
#
# Estimate the parameters of your finite mixture of normals model. Attach your (heavily) modified `.stan` file to your submission so that we may run it when graded your work.
#
# Please be sure to address the following questions about $\theta$ inference:
#
# 1. Are you sure your posterior for $\theta$ is identifiable?
# 2. What did you spend most of your time doing to get this to be so?
# 3. Discuss the *meaning* of your group categories that you found (i.e. which group is the "healthy" group, etc. etc.)
#
# Please report all the usual stuff, too.
#
# Regarding the $z$ inference:
#
# 4. Should you pay attention to $\hat{R}$ diagnostics for `label_prob` variables?
# 5. Which individual is one of the most difficult to categorize? Why do you think this is interesting to identify?
# 6. What percentage of the time do your individual person labels correspond to the labels given to you in the `.csv` file?
#
# Finally:
#
# 7. Are there any interesting scientific questions that are not addressed by this finite mixture model?

# %%
print(diab[["group", "group_num"]].drop_duplicates().sort_values("group_num"))
# Out:
#                  group  group_num
# 0               Normal        NaN
# 58   Chemical_Diabetic        NaN
# 112     Overt_Diabetic        NaN

# %%
# Assign numeric group labels
group_map = {
    "Normal": 0,
    "Chemical_Diabetic": 1,
    "Overt_Diabetic": 2
}
diab["group_num"] = diab["group"].map(group_map)

# Select features
X = diab[["relwt", "glufast", "glutest", "instest", "sspg"]]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Extract labels
labels = diab["group_num"].values.astype(int)

# Split standardized data by group
X_0 = X_scaled[labels == 0]
X_1 = X_scaled[labels == 1]
X_2 = X_scaled[labels == 2]

# Calculate empirical covariance matrices
S0 = np.cov(X_0, rowvar=False)
S1 = np.cov(X_1, rowvar=False)
S2 = np.cov(X_2, rowvar=False)

# Set degrees of freedom
D = X.shape[1]
nu = [D + 3] * 3  # Conservative degrees of freedom per group

# Compute scale matrices Psi = S * (nu - D - 1)
Psi_0 = S0 * (nu[0] - D - 1)
Psi_1 = S1 * (nu[1] - D - 1)
Psi_2 = S2 * (nu[2] - D - 1)

# Prepare Stan data
stan_data = {
    "N": X_scaled.shape[0],
    "D": D,
    "H": 3,
    "y": X_scaled,
    "nu": nu,
    "Psi": [Psi_0, Psi_1, Psi_2]
}

# Compile and sample
model = CmdStanModel(stan_file="finite_mixture_normals.stan")
fit = model.sample(
    data=stan_data,
    chains=4,
    parallel_chains=4,
    iter_warmup=1000,
    iter_sampling=1000,
    show_progress=True
)
# Out:
# 12:16:10 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 12:21:24 - cmdstanpy - INFO - CmdStan done processing.
# 12:21:24 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,4] = -nan, but random variable[4,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: LDLT_Factor of random variable is not positive definite.  last conditional variance is -nan. (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# Exception: inv_wishart_lpdf: LDLT_Factor of random variable is not positive definite.  last conditional variance is 0. (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: LDLT_Factor of random variable is not positive definite.  last conditional variance is 0. (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: LDLT_Factor of random variable is not positive definite.  last conditional variance is 0. (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: LDLT_Factor of random variable is not positive definite.  last conditional variance is 0. (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: LDLT_Factor of random variable is not positive definite.  last conditional variance is 0. (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -inf, but random variable[2,1] = -inf (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -inf, but random variable[2,1] = -inf (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: LDLT_Factor of random variable is not positive definite.  last conditional variance is -nan. (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,3] = -nan, but random variable[3,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = -nan, but random variable[2,1] = -nan (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# 	Exception: inv_wishart_lpdf: random variable is not symmetric. random variable[1,2] = inf, but random variable[2,1] = inf (in 'finite_mixture_normals.stan', line 23, column 4 to column 42)
# Consider re-running with show_console=True if the above output is unclear!
# 12:21:24 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 3 had 1 divergent transitions (0.1%)
# 	Use the "diagnose()" method on the CmdStanMCMC object to see further information.

# %%
fit.diagnose()
# Out:
# "Checking sampler transitions treedepth.\nTreedepth satisfactory for all transitions.\n\nChecking sampler transitions for divergences.\n1 of 1000 (0.10%) transitions ended with a divergence.\nThese divergent transitions indicate that HMC is not fully able to explore the posterior distribution.\nTry increasing adapt delta closer to 1.\nIf this doesn't remove all divergences, try to reparameterize the model.\n\nChecking E-BFMI - sampler transitions HMC potential energy.\nThe E-BFMI, 0.05, is below the nominal threshold of 0.30 which suggests that HMC may have trouble exploring the target distribution.\nIf possible, try to reparameterize the model.\n\nRank-normalized split effective sample size satisfactory for all parameters.\n\nThe following parameters had rank-normalized split R-hat greater than 1.01:\n  lambda[1], lambda[2], lambda[3], mu[1,1], mu[2,1], mu[3,1], mu[1,2], mu[2,2], mu[3,2], mu[1,3], mu[2,3], mu[3,3], mu[1,4], mu[2,4], mu[3,4], mu[1,5], mu[2,5], mu[3,5], Sigma[1,1,1], Sigma[2,1,1], Sigma[3,1,1], Sigma[1,2,1], Sigma[2,2,1], Sigma[3,2,1], Sigma[1,3,1], Sigma[2,3,1], Sigma[3,3,1], Sigma[1,4,1], Sigma[2,4,1], Sigma[3,4,1], Sigma[1,5,1], Sigma[2,5,1], Sigma[3,5,1], Sigma[1,1,2], Sigma[2,1,2], Sigma[3,1,2], Sigma[1,2,2], Sigma[2,2,2], Sigma[3,2,2], Sigma[1,3,2], Sigma[2,3,2], Sigma[3,3,2], Sigma[1,4,2], Sigma[2,4,2], Sigma[3,4,2], Sigma[1,5,2], Sigma[2,5,2], Sigma[3,5,2], Sigma[1,1,3], Sigma[2,1,3], Sigma[3,1,3], Sigma[1,2,3], Sigma[2,2,3], Sigma[3,2,3], Sigma[1,3,3], Sigma[2,3,3], Sigma[3,3,3], Sigma[1,4,3], Sigma[2,4,3], Sigma[3,4,3], Sigma[1,5,3], Sigma[2,5,3], Sigma[3,5,3], Sigma[1,1,4], Sigma[2,1,4], Sigma[3,1,4], Sigma[1,2,4], Sigma[2,2,4], Sigma[3,2,4], Sigma[1,3,4], Sigma[2,3,4], Sigma[3,3,4], Sigma[1,4,4], Sigma[2,4,4], Sigma[3,4,4], Sigma[1,5,4], Sigma[2,5,4], Sigma[3,5,4], Sigma[1,1,5], Sigma[2,1,5], Sigma[3,1,5], Sigma[1,2,5], Sigma[2,2,5], Sigma[3,2,5], Sigma[1,3,5], Sigma[2,3,5], Sigma[3,3,5], Sigma[1,4,5], Sigma[2,4,5], Sigma[3,4,5], Sigma[1,5,5], Sigma[2,5,5], Sigma[3,5,5], label_prob[1,1], label_prob[2,1], label_prob[3,1], label_prob[4,1], label_prob[5,1], label_prob[6,1], label_prob[7,1], label_prob[8,1], label_prob[9,1], label_prob[10,1], label_prob[11,1], label_prob[12,1], label_prob[13,1], label_prob[14,1], label_prob[15,1], label_prob[16,1], label_prob[17,1], label_prob[18,1], label_prob[19,1], label_prob[20,1], label_prob[21,1], label_prob[22,1], label_prob[23,1], label_prob[24,1], label_prob[25,1], label_prob[26,1], label_prob[27,1], label_prob[28,1], label_prob[29,1], label_prob[30,1], label_prob[31,1], label_prob[32,1], label_prob[33,1], label_prob[34,1], label_prob[35,1], label_prob[36,1], label_prob[37,1], label_prob[38,1], label_prob[39,1], label_prob[40,1], label_prob[41,1], label_prob[42,1], label_prob[43,1], label_prob[44,1], label_prob[45,1], label_prob[46,1], label_prob[47,1], label_prob[48,1], label_prob[49,1], label_prob[50,1], label_prob[51,1], label_prob[52,1], label_prob[53,1], label_prob[54,1], label_prob[55,1], label_prob[56,1], label_prob[57,1], label_prob[58,1], label_prob[59,1], label_prob[60,1], label_prob[61,1], label_prob[62,1], label_prob[63,1], label_prob[64,1], label_prob[65,1], label_prob[66,1], label_prob[67,1], label_prob[68,1], label_prob[69,1], label_prob[70,1], label_prob[71,1], label_prob[72,1], label_prob[73,1], label_prob[74,1], label_prob[75,1], label_prob[76,1], label_prob[77,1], label_prob[78,1], label_prob[79,1], label_prob[80,1], label_prob[81,1], label_prob[82,1], label_prob[83,1], label_prob[84,1], label_prob[85,1], label_prob[87,1], label_prob[88,1], label_prob[90,1], label_prob[91,1], label_prob[92,1], label_prob[94,1], label_prob[95,1], label_prob[96,1], label_prob[97,1], label_prob[98,1], label_prob[100,1], label_prob[101,1], label_prob[102,1], label_prob[103,1], label_prob[104,1], label_prob[105,1], label_prob[106,1], label_prob[107,1], label_prob[108,1], label_prob[109,1], label_prob[110,1], label_prob[111,1], label_prob[112,1], label_prob[115,1], ...

# %%
# Extract summary as a DataFrame
summary_df = fit.summary()

# Subset to R-hat only
rhat_df = summary_df[['R_hat']].dropna().sort_values(by='R_hat', ascending=False)

# Show worst offenders (Rhat far from 1)
display(rhat_df[rhat_df['R_hat'] > 1.01])
# Out:
#                     R_hat
# label_prob[2,1]   2.08572
# label_prob[18,1]  2.06292
# label_prob[16,1]  2.06244
# label_prob[28,1]  2.06123
# label_prob[37,1]  2.05190
# ...                   ...
# Sigma[2,2,2]      1.01501
# Sigma[2,3,3]      1.01472
# label_prob[19,2]  1.01435
# Sigma[2,3,4]      1.01364
# Sigma[2,4,3]      1.01364
#
# [165 rows x 1 columns]

# %%
# Convert draws to DataFrame
df = fit.draws_pd()

# Select parameter(s) to plot
params = ['mu[1,1]', 'mu[2,1]', 'lambda[1]']  # change these to whatever you want

# Create trace plots
fig, axes = plt.subplots(len(params), 1, figsize=(10, 2.5 * len(params)), sharex=True)

if len(params) == 1:
    axes = [axes]

for i, param in enumerate(params):
    axes[i].plot(df[param], color='steelblue', linewidth=0.7)
    axes[i].set_title(f"Trace Plot for {param}")
    axes[i].set_ylabel("Value")
    axes[i].grid(True)

axes[-1].set_xlabel("Iteration")
plt.tight_layout()
plt.show()

# %%
# Extract label probabilities
label_probs = fit.generated_quantities_pd().filter(like="label_prob")
label_probs_matrix = label_probs.values.reshape(-1, N, H).mean(axis=0)
assigned_labels = label_probs_matrix.argmax(axis=1)

# Add to original DataFrame
diab["assigned_cluster"] = assigned_labels

# Visualize
sns.pairplot(diab, hue="assigned_cluster", vars=features, palette="Set2")
plt.suptitle("Pairplot by Assigned Cluster", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Hints
#
# **Expect to do a lot of experimentation with**
#  - which columns to transform or remove so that everything is conditionally normal,
#  - how many clusters to assume you have, and most of all
#  - **how to properly describe your prior beliefs**.
#
# The biggest difficult you will have is trying to specify priors to make the posterior identifiable--to know which cluster group is which. **Remember what we said about $\hat{R}$s in lecture!** Dealing with this also helps with the speed of the algorithm.
#
# More hints:
#
#  1. Use scatterplots (pairwise or 3-d) to help you visualize how many clusters there need to be. Use Occam's razor!
#  2. Feel free to "cheat" in order to come up with priors that identify your posterior.
#  3. While you're figuring everything out, it might be faster to prototype to temporarily restrict your attention to a random subset of the data.
